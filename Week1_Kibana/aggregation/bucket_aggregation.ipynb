# %% [markdown]
# ### 목록
# * 준비
#     * [사용할 라이브러리 불러오기](#lib)
#     * [엘라스틱서치 환경 설정하기](#es_setting)
#     * [엘라스틱서치에서 데이터 조회하기](#es_load)
#     * [조회한 데이터를 테이블 형태로 만들기](#df)
# * Bucket Aggregation
#     * [Date Histogram Aggregation](#dh)
#     * [Date Range Aggregation](#dr)
#     * [Histogram Aggregation](#ha)
#     * [Range Aggregation](#ra)
#     * [Terms Aggregation](#ta)
#     * [Filters Aggregation](#fa)
# ---

# %% [markdown]
# ### 준비

# %% [markdown]
# <a name='lib'></a>
# #### 사용할 라이브러리 불러오기

# %%
import pandas as pd
from elasticsearch import Elasticsearch
import datetime

# %% [markdown]
# <a name='es_setting'></a>
# #### 엘라스틱서치 환경 설정하기

# %%
# 적당한 값을 넣지 않으면 오류가 납니다
es = Elasticsearch()
es_index = 'test_index'
es_type = 'test_type'

# %% [markdown]
# <a name='es_load'></a>
# #### 엘라스틱서치에서 데이터 조회하기

# %%
x = es.search(
      index='test_index', 
      doc_type='test_type', 
      body={
        '_source' : ['결제카드','고객나이', '구매사이트', '상품가격', '주문시간'],
        'query' : {
            'match_all' : {}
        },
        'size' : 50
      }
)

# %% [markdown]
# <a name='df'></a>
# #### 조회한 데이터를 테이블 형태로 만들기

# %%
df = pd.DataFrame([x['hits']['hits'][idx]['_source'] for idx, _ in enumerate(x['hits']['hits'])])
df
# Out:
#    결제카드  고객나이 구매사이트   상품가격                 주문시간
# 0    국민    28    옥션   8000  2017-11-01T05:45:01
# 1    하나    32    티몬  13000  2017-11-09T16:58:07
# 2    국민    35   위메프  22000  2017-11-06T20:03:26
# 3    국민    38   GS샵  21000  2017-11-03T18:29:35
# 4    롯데    28    쿠팡  21000  2017-11-09T22:37:36
# 5    신한    30    티몬  13000  2017-11-05T00:41:55
# 6    신한    41    옥션  15000  2017-11-06T00:27:44
# 7    국민    38    쿠팡  12000  2017-11-09T00:40:16
# 8    우리    39  11번가  10000  2017-11-06T10:28:26
# 9    국민    39   GS샵  17000  2017-11-08T02:00:16
# 10   국민    33   GS샵   6000  2017-11-07T15:29:40
# 11   국민    25   g마켓   5000  2017-11-09T17:35:41
# 12   우리    33  11번가  17000  2017-11-10T15:53:17
# 13   우리    27   위메프  17000  2017-11-02T05:28:18
# 14   국민    44    옥션  21000  2017-11-04T08:22:51
# 15   신한    20    티몬  28000  2017-11-03T20:15:22
# 16   우리    43  11번가  14000  2017-11-06T06:26:34
# 17   롯데    27   GS샵   8000  2017-11-10T17:03:49
# 18   우리    35    옥션  23000  2017-11-05T04:57:07
# 19   신한    30    쿠팡  25000  2017-11-04T14:45:44
# 20   국민    28   GS샵  21000  2017-11-06T12:47:17
# 21   우리    26   GS샵  11000  2017-11-08T01:14:23
# 22   국민    29  11번가  17000  2017-11-03T10:37:56
# 23   하나    33    옥션  19000  2017-11-06T04:46:55
# 24   롯데    42   g마켓  10000  2017-11-02T04:33:20
# 25   국민    22  11번가  18000  2017-11-05T00:20:15
# 26   삼성    34   g마켓   5000  2017-11-07T02:40:42
# 27   하나    29  11번가  26000  2017-11-05T04:18:52
# 28   국민    45   GS샵  17000  2017-11-09T21:57:00
# 29   신한    35   g마켓   9000  2017-11-04T08:22:24
# 30   우리    38  11번가   9000  2017-11-07T01:32:11
# 31   우리    38   g마켓   7000  2017-11-09T03:28:29
# 32   롯데    41    옥션  27000  2017-11-10T23:15:29
# 33   신한    19    티몬  23000  2017-11-04T20:38:58
# 34   하나    43   g마켓  10000  2017-11-02T19:50:09
# 35   우리    34    티몬   5000  2017-11-09T17:10:08
# 36   하나    17  11번가  27000  2017-11-01T13:52:01
# 37   시티    41   위메프  19000  2017-11-10T15:39:55
# 38   우리    27    옥션  20000  2017-11-09T14:50:53
# 39   국민    18    옥션  26000  2017-11-08T10:27:28
# 40   신한    22   GS샵  22000  2017-11-03T20:24:56
# 41   롯데    29   g마켓  12000  2017-11-04T05:32:27
# 42   우리    26    옥션  23000  2017-11-02T13:19:26
# 43   롯데    31  11번가  18000  2017-11-04T02:16:07
# 44   하나    45   위메프  22000  2017-11-10T16:14:55
# 45   하나    24   g마켓  13000  2017-11-07T18:24:38
# 46   우리    36   g마켓  12000  2017-11-04T11:48:21
# 47   신한    17   GS샵  11000  2017-11-03T01:42:38
# 48   우리    34    티몬   9000  2017-11-07T03:44:21
# 49   우리    19  11번가  27000  2017-11-08T03:43:55

# %% [markdown]
# ### Bucket Aggregation

# %% [markdown]
# <a name='dh'></a>
# #### Date Histogram Aggregation
#
# : Date Field를 일정 간격으로 나눈 구간으로 Bucket(혹은 Group) 생성

# %%
new_df = df.copy()
new_df.index = pd.to_datetime(new_df['주문시간'])
new_df_rs = new_df.resample('D').count().iloc[:, 1:2]
new_df_rs = pd.DataFrame({'주문시간' : new_df_rs.index, '개수' : new_df_rs.values.ravel()})
new_df_rs[['주문시간', '개수']]
# Out:
#         주문시간  개수
# 0 2017-11-01   2
# 1 2017-11-02   4
# 2 2017-11-03   5
# 3 2017-11-04   7
# 4 2017-11-05   4
# 5 2017-11-06   6
# 6 2017-11-07   5
# 7 2017-11-08   4
# 8 2017-11-09   8
# 9 2017-11-10   5

# %% [markdown]
# <a name="dr"></a>
# #### Date Range Aggregation
# :  각 Date 구간의 시작과 끝점을 설정하여 Bucket 생성한다

# %% [markdown]
# ##### 11월1일 ~ 11월3일 구간

# %%
new_df_rs = new_df['2017-11-01' : '2017-11-03'].resample('D').count().iloc[:, 1:2]
new_df_rs = pd.DataFrame({'주문시간' : new_df_rs.index, '개수' : new_df_rs.values.ravel()})
new_df_rs[['주문시간', '개수']]
# Out:
#         주문시간  개수
# 0 2017-11-01   2
# 1 2017-11-02   4
# 2 2017-11-03   5

# %%
new_df['2017-11-01' : '2017-11-03'].count()[0]
# Out:
# 11

# %% [markdown]
# ##### 11월4일 ~ 11월10일 구간

# %%
new_df_rs = new_df['2017-11-04' : '2017-11-10'].resample('D').count().iloc[:, 1:2]
new_df_rs = pd.DataFrame({'주문시간' : new_df_rs.index, '개수' : new_df_rs.values.ravel()})
new_df_rs[['주문시간', '개수']]
# Out:
#         주문시간  개수
# 0 2017-11-04   7
# 1 2017-11-05   4
# 2 2017-11-06   6
# 3 2017-11-07   5
# 4 2017-11-08   4
# 5 2017-11-09   8
# 6 2017-11-10   5

# %%
new_df['2017-11-04' : '2017-11-10'].count()[0]
# Out:
# 39

# %% [markdown]
# <a name="ha"></a>
# #### Histogram Aggregation
# : Number Field의 각 구간으로 Bucket 생성한다

# %%
bins = range(10, 51, 10)
group_names = ['10대', '20대', '30대', '40대']
df['연령대'] = pd.cut(df['고객나이'], bins, labels=group_names)
df_gb = df.groupby(by='연령대').count().iloc[:, 1:2]
df_gb = pd.DataFrame({'연령대' : df_gb.index, '개수' : df_gb.values.ravel()})
df_gb[['연령대', '개수']]
# Out:
#    연령대  개수
# 0  10대   6
# 1  20대  17
# 2  30대  18
# 3  40대   9

# %% [markdown]
# <a name="ra"></a>
# #### Range Aggregation
# : 옵션으로 설정한 Number Field의 각 구간으로 Bucket 생성한다

# %% [markdown]
# * 상품가격이 만원 이하 : [0, 10,000)
# * 상품가격이 이만원 이하 : [10,000 , 20000)
# * 상품가격이 삼만원 이하 : [20,000 , 30000)

# %%
bins = range(0, 30001, 10000)
group_names = ['만원 이하', '이만원 이하', '삼만원 이하']
df['가격대'] = pd.cut(df['상품가격'], bins, labels=group_names)
df_gb = df.groupby(by='가격대').count().iloc[:, 1:2]
df_gb = pd.DataFrame({'가격대' : df_gb.index, '개수' : df_gb.values.ravel()})
df_gb[['가격대', '개수']]
# Out:
#       가격대  개수
# 0   만원 이하  13
# 1  이만원 이하  20
# 2  삼만원 이하  17

# %% [markdown]
# <a name="ta"></a>
# #### Terms Aggregation
# : 선택한 Term를 기준으로 Bucket 생성한다

# %% [markdown]
# * 카드별 결제 건수가
# * 가장 많은 2개의 카드 별
# * 최대 결제 금액을 구하시오

# %%
# 카드별 결제 건수가...
card = df.groupby(by='결제카드').count().iloc[:, 1:2]
card_df = pd.DataFrame({'결제카드' : card.index, '개수' : card.values.ravel()})
card_df[['결제카드', '개수']]
# Out:
#   결제카드  개수
# 0   국민  13
# 1   롯데   6
# 2   삼성   1
# 3   시티   1
# 4   신한   8
# 5   우리  14
# 6   하나   7

# %%
# ,,,가장 많은 2개의 카드...
card_sort = card_df.sort_values(by='개수', ascending=False)[:2]
card_sort[['결제카드', '개수']]
# Out:
#   결제카드  개수
# 5   우리  14
# 0   국민  13

# %%
# ...최대 결제 금액을 구하시오
max(df[df['결제카드'] == '우리']['상품가격'])
# Out:
# 27000

# %%
# ...최대 결제 금액을 구하시오
max(df[df['결제카드'] == '국민']['상품가격'])
# Out:
# 26000

# %% [markdown]
# <a name="fa"></a>
# #### Filters Aggregation
# : Query String으로 작성한 조건 만족하는 Bucket 생성한다

# %% [markdown]
# * 구매 사이트가 옥션, 티몬인 사람들의
# * 구매 사이트별 최소 구매가격을 구하시오

# %%
# 구매 사이트가 옥션, 티몬인 사람들의...
df_filter = df[df['구매사이트'].str.contains('옥션|티몬')]
df_filter
# Out:
#    결제카드  고객나이 구매사이트   상품가격                 주문시간  연령대     가격대
# 0    국민    28    옥션   8000  2017-11-01T05:45:01  20대   만원 이하
# 1    하나    32    티몬  13000  2017-11-09T16:58:07  30대  이만원 이하
# 5    신한    30    티몬  13000  2017-11-05T00:41:55  20대  이만원 이하
# 6    신한    41    옥션  15000  2017-11-06T00:27:44  40대  이만원 이하
# 14   국민    44    옥션  21000  2017-11-04T08:22:51  40대  삼만원 이하
# 15   신한    20    티몬  28000  2017-11-03T20:15:22  10대  삼만원 이하
# 18   우리    35    옥션  23000  2017-11-05T04:57:07  30대  삼만원 이하
# 23   하나    33    옥션  19000  2017-11-06T04:46:55  30대  이만원 이하
# 32   롯데    41    옥션  27000  2017-11-10T23:15:29  40대  삼만원 이하
# 33   신한    19    티몬  23000  2017-11-04T20:38:58  10대  삼만원 이하
# 35   우리    34    티몬   5000  2017-11-09T17:10:08  30대   만원 이하
# 38   우리    27    옥션  20000  2017-11-09T14:50:53  20대  이만원 이하
# 39   국민    18    옥션  26000  2017-11-08T10:27:28  10대  삼만원 이하
# 42   우리    26    옥션  23000  2017-11-02T13:19:26  20대  삼만원 이하
# 48   우리    34    티몬   9000  2017-11-07T03:44:21  30대   만원 이하

# %%
# ...구매사이트별 최소 구매고객을 구하시오
min(df_filter[df_filter['구매사이트']=='티몬']['상품가격'])
# Out:
# 5000

# %%
# ...구매사이트별 최소 구매고객을 구하시오
min(df_filter[df_filter['구매사이트']=='옥션']['상품가격'])
# Out:
# 8000
